# %%
# !pip install basilica
# Out:
# Collecting basilica
#   Downloading https://files.pythonhosted.org/packages/68/19/6216f1c0ad6d0f738bd1061cb5c65097021b41f3891046fac87bc4c4e1ae/basilica-0.2.8.tar.gz
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from basilica) (2.23.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from basilica) (1.15.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from basilica) (7.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->basilica) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->basilica) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->basilica) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->basilica) (1.24.3)
# Building wheels for collected packages: basilica
#   Building wheel for basilica (setup.py) ... done
#   Created wheel for basilica: filename=basilica-0.2.8-cp36-none-any.whl size=4711 sha256=ef2a39ab3d46ec9c1545cf1a8540c37b557a2b9cf59dc6bbce6f9078c71740e1
#   Stored in directory: /root/.cache/pip/wheels/31/18/9f/46f6face8baf98e31b52bf91a0d76930ec76860f9e9211104d
# Successfully built basilica
# Installing collected packages: basilica
# Successfully installed basilica-0.2.8

# %%
import tweepy
import basilica

# %%
## ADD YOUR CREDENTIALS HERE
TWITTER_CONSUMER_API_KEY = 'qt8iUNpkfkLn8RiKcPqazj0xN'
TWITTER_CONSUMER_API_SECRET = '89k5tyaqBPaa78CSVCgqaNoMz412gQDWfPBhUm1RIe6nDJEXcp'
TWITTER_ACCESS_TOKEN = '1286889907877580811-W5LUdN4nbgJCoN7FSwbMd7iqibC9fP'
TWITTER_ACCESS_TOKEN_SECRET = 'g3bu5v9WKYTT04llFI77Q4AMyP5sf0m8IMHWzDd7TWTG0'
BASILICA_KEY = 'feb871e9-4e89-deac-5283-9dbffad450eb'

# %%
TWITTER_AUTH = tweepy.OAuthHandler(TWITTER_CONSUMER_API_KEY,TWITTER_CONSUMER_API_SECRET)
TWITTER_AUTH.set_access_token(TWITTER_ACCESS_TOKEN, TWITTER_ACCESS_TOKEN_SECRET)
TWITTER = tweepy.API(TWITTER_AUTH)
BASILICA = basilica.Connection(BASILICA_KEY)

# %%
dir(TWITTER)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_list_members',
#  '_lookup_friendships',
#  '_lookup_users',
#  '_pack_image',
#  '_remove_list_members',
#  '_statuses_lookup',
#  'add_list_member',
#  'add_list_members',
#  'api_root',
#  'auth',
#  'blocks',
#  'blocks_ids',
#  'cache',
#  'compression',
#  'configuration',
#  'create_block',
#  'create_favorite',
#  'create_friendship',
#  'create_list',
#  'create_saved_search',
#  'destroy_block',
#  'destroy_direct_message',
#  'destroy_favorite',
#  'destroy_friendship',
#  'destroy_list',
#  'destroy_saved_search',
#  'destroy_status',
#  'direct_messages',
#  'favorites',
#  'followers',
#  'followers_ids',
#  'friends',
#  'friends_ids',
#  'friendships_incoming',
#  'friendships_outgoing',
#  'geo_id',
#  'geo_search',
#  'geo_similar_places',
#  'get_direct_message',
#  'get_list',
#  'get_oembed',
#  'get_saved_search',
#  'get_settings',
#  'get_status',
#  'get_user',
#  'home_timeline',
#  'host',
#  'list_members',
#  'list_subscribers',
#  'list_timeline',
#  'lists_all',
#  'lists_memberships',
#  'lists_subscriptions',
#  'lookup_friendships',
#  'lookup_users',
#  'me',
#  'media_upload',
#  'mentions_timeline',
#  'parser',
#  'proxy',
#  'rate_limit_status',
#  'related_results',
#  'remove_list_member',
#  'remove_list_members',
#  'report_spam',
#  'retry_count',
#  'retry_delay',
#  'retry_errors',
#  'retweet',
#  'retweeters',
#  'retweets',
#  'retweets_of_me',
#  'reverse_geocode',
#  'saved_searches',
#  'search',
#  'search_host',
#  'search_root',
#  'search_users',
#  'send_direct_message',
#  'sent_direct_messages',
#  'set_delivery_device',
#  'set_settings',
#  'show_friendship',
#  'show_list_member',
#  'show_list_subscriber',
#  'statuses_lookup',
#  'subscribe_list',
#  'suggested_categories',
#  'suggested_users',
#  'suggested_users_tweets',
#  'supported_languages',
#  'timeout',
#  'trends_available',
#  'trends_closest',
#  'trends_place',
#  'unretweet',
#  'unsubscribe_list',
#  'update_list',
#  'update_profile',
#  'update_profile_background_image',
#  'update_profile_banner',
#  'update_profile_image',
#  'update_status',
#  'update_with_media',
#  'upload_host',
#  'upload_root',
#  'user_timeline',
#  'verify_credentials',
#  'wait_on_rate_limit',
#  'wait_on_rate_limit_notify']

# %%
twitter_user = TWITTER.get_user('elonmusk')
twitter_user
# Out:
# User(_api=<tweepy.api.API object at 0x7f037fe84f60>, _json={'id': 44196397, 'id_str': '44196397', 'name': 'Elon Musk', 'screen_name': 'elonmusk', 'location': '', 'profile_location': None, 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 37805890, 'friends_count': 95, 'listed_count': 55088, 'created_at': 'Tue Jun 02 20:12:29 +0000 2009', 'favourites_count': 6395, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 11972, 'lang': None, 'status': {'created_at': 'Wed Aug 12 14:28:34 +0000 2020', 'id': 1293554977965670402, 'id_str': '1293554977965670402', 'text': '@Teslarati No surprise', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Teslarati', 'name': 'TESLARATI', 'id': 1308211178, 'id_str': '1308211178', 'indices': [0, 10]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1293502984383606787, 'in_reply_to_status_id_str': '1293502984383606787', 'in_reply_to_user_id': 1308211178, 'in_reply_to_user_id_str': '1308211178', 'in_reply_to_screen_name': 'Teslarati', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 142, 'favorite_count': 3970, 'favorited': False, 'retweeted': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1289966861333835776/LVnVeLln_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1289966861333835776/LVnVeLln_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44196397/1576183471', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, id=44196397, id_str='44196397', name='Elon Musk', screen_name='elonmusk', location='', profile_location=None, description='', url=None, entities={'description': {'urls': []}}, protected=False, followers_count=37805890, friends_count=95, listed_count=55088, created_at=datetime.datetime(2009, 6, 2, 20, 12, 29), favourites_count=6395, utc_offset=None, time_zone=None, geo_enabled=False, verified=True, statuses_count=11972, lang=None, status=Status(_api=<tweepy.api.API object at 0x7f037fe84f60>, _json={'created_at': 'Wed Aug 12 14:28:34 +0000 2020', 'id': 1293554977965670402, 'id_str': '1293554977965670402', 'text': '@Teslarati No surprise', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Teslarati', 'name': 'TESLARATI', 'id': 1308211178, 'id_str': '1308211178', 'indices': [0, 10]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1293502984383606787, 'in_reply_to_status_id_str': '1293502984383606787', 'in_reply_to_user_id': 1308211178, 'in_reply_to_user_id_str': '1308211178', 'in_reply_to_screen_name': 'Teslarati', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 142, 'favorite_count': 3970, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 8, 12, 14, 28, 34), id=1293554977965670402, id_str='1293554977965670402', text='@Teslarati No surprise', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'scr ...

# %%
twitter_user.id
# Out:
# 44196397

# %%
tweets = twitter_user.timeline()
tweets
# Out:
# [Status(_api=<tweepy.api.API object at 0x7f037fe84f60>, _json={'created_at': 'Wed Aug 12 14:28:34 +0000 2020', 'id': 1293554977965670402, 'id_str': '1293554977965670402', 'text': '@Teslarati No surprise', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Teslarati', 'name': 'TESLARATI', 'id': 1308211178, 'id_str': '1308211178', 'indices': [0, 10]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1293502984383606787, 'in_reply_to_status_id_str': '1293502984383606787', 'in_reply_to_user_id': 1308211178, 'in_reply_to_user_id_str': '1308211178', 'in_reply_to_screen_name': 'Teslarati', 'user': {'id': 44196397, 'id_str': '44196397', 'name': 'Elon Musk', 'screen_name': 'elonmusk', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 37805892, 'friends_count': 95, 'listed_count': 55088, 'created_at': 'Tue Jun 02 20:12:29 +0000 2009', 'favourites_count': 6395, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 11972, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1289966861333835776/LVnVeLln_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1289966861333835776/LVnVeLln_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44196397/1576183471', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 142, 'favorite_count': 3971, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 8, 12, 14, 28, 34), id=1293554977965670402, id_str='1293554977965670402', text='@Teslarati No surprise', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Teslarati', 'name': 'TESLARATI', 'id': 1308211178, 'id_str': '1308211178', 'indices': [0, 10]}], 'urls': []}, source='Twitter for iPhone', source_url='http://twitter.com/download/iphone', in_reply_to_status_id=1293502984383606787, in_reply_to_status_id_str='1293502984383606787', in_reply_to_user_id=1308211178, in_reply_to_user_id_str='1308211178', in_reply_to_screen_name='Teslarati', author=User(_api=<tweepy.api.API object at 0x7f037fe84f60>, _json={'id': 44196397, 'id_str': '44196397', 'name': 'Elon Musk', 'screen_name': 'elonmusk', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 37805892, 'friends_count': 95, 'listed_count': 55088, 'created_at': 'Tue Jun 02 20:12:29 +0000 2009', 'favourites_count': 6395, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 11972, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1289966861333835776/LVnVeLln_normal.jpg', 'profile_image_url_https ...
#  Status(_api=<tweepy.api.API object at 0x7f037fe84f60>, _json={'created_at': 'Tue Aug 11 22:19:28 +0000 2020', 'id': 1293311095013220353, 'id_str': '1293311095013220353', 'text': '@Teslarati Aiming to make it super fun!', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Teslarati', 'name': 'TESLARATI', 'id': 1308211178, 'id_str': '1308211178', 'indices': [0, 10]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1293144910917402629, 'in_reply_to_status_id_str': '1293144910917402629', 'in_reply_to_user_id': 1308211178, 'in_reply_to_user_id_str': '1308211178', 'in_reply_to_screen_name': 'Teslarati', 'user': {'id': 44196397, 'id_str': '44196397', 'name': 'Elon Musk', 'screen_name': 'elonmusk', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 37805892, 'friends_count': 95, 'listed_count': 55088, 'created_at': 'Tue Jun 02 20:12:29 +0000 2009', 'favourites_count': 6395, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 11972, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1289966861333835776/LVnVeLln_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1289966861333835776/LVnVeLln_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44196397/1576183471', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 308, 'favorite_count': 9114, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 8, 11, 22, 19, 28), id=1293311095013220353, id_str='1293311095013220353', text='@Teslarati Aiming to make it super fun!', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Teslarati', 'name': 'TESLARATI', 'id': 1308211178, 'id_str': '1308211178', 'indices': [0, 10]}], 'urls': []}, source='Twitter for iPhone', source_url='http://twitter.com/download/iphone', in_reply_to_status_id=1293144910917402629, in_reply_to_status_id_str='1293144910917402629', in_reply_to_user_id=1308211178, in_reply_to_user_id_str='1308211178', in_reply_to_screen_name='Teslarati', author=User(_api=<tweepy.api.API object at 0x7f037fe84f60>, _json={'id': 44196397, 'id_str': '44196397', 'name': 'Elon Musk', 'screen_name': 'elonmusk', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 37805892, 'friends_count': 95, 'listed_count': 55088, 'created_at': 'Tue Jun 02 20:12:29 +0000 2009', 'favourites_count': 6395, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 11972, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1289966861333835776/LVnVeLln_nor ...
#  Status(_api=<tweepy.api.API object at 0x7f037fe84f60>, _json={'created_at': 'Tue Aug 11 18:36:28 +0000 2020', 'id': 1293254976739799040, 'id_str': '1293254976739799040', 'text': '@Teslarati A little toastier each flight', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Teslarati', 'name': 'TESLARATI', 'id': 1308211178, 'id_str': '1308211178', 'indices': [0, 10]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1293108663775907842, 'in_reply_to_status_id_str': '1293108663775907842', 'in_reply_to_user_id': 1308211178, 'in_reply_to_user_id_str': '1308211178', 'in_reply_to_screen_name': 'Teslarati', 'user': {'id': 44196397, 'id_str': '44196397', 'name': 'Elon Musk', 'screen_name': 'elonmusk', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 37805892, 'friends_count': 95, 'listed_count': 55088, 'created_at': 'Tue Jun 02 20:12:29 +0000 2009', 'favourites_count': 6395, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 11972, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1289966861333835776/LVnVeLln_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1289966861333835776/LVnVeLln_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44196397/1576183471', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 199, 'favorite_count': 6250, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 8, 11, 18, 36, 28), id=1293254976739799040, id_str='1293254976739799040', text='@Teslarati A little toastier each flight', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': '
id': 44196397, 'id_str': '44196397', 'name': 'Elon Musk', 'screen_name': 'elonmusk', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls ...
#  Status(_api=<tweepy.api.API object at 0x7f037fe84f60>, _json={'created_at': 'Tue Aug 11 01:29:45 +0000 2020', 'id': 1292996594371948545, 'id_str': '1292996594371948545', 'text': '@Mark_Goldberg_ @Tesla Note the fabulous plaid jacket &amp; gingham shirt combo 🤣', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Mark_Goldberg_', 'name': 'Mark Goldberg', 'id': 932730431434211328, 'id_str': '932730431434211328', 'indices': [0, 15]}, {'screen_name': 'Tesla', 'name': 'Tesla', 'id': 13298072, 'id_str': '13298072', 'indices': [16, 22]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1292818184588886016, 'in_reply_to_status_id_str': '1292818184588886016', 'in_reply_to_user_id': 932730431434211328, 'in_reply_to_user_id_str': '932730431434211328', 'in_reply_to_screen_name': 'Mark_Goldberg_', 'user': {'id': 44196397, 'id_str': '44196397', 'name': 'Elon Musk', 'screen_name': 'elonmusk', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 37805892, 'friends_count': 95, 'listed_count': 55088, 'created_at': 'Tue Jun 02 20:12:29 +0000 2009', 'favourites_count': 6395, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 11972, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1289966861333835776/LVnVeLln_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1289966861333835776/LVnVeLln_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44196397/1576183471', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 188, 'favorite_count': 11297, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 8, 11, 1, 29, 45), id=1292996594371948545, id_str='1292996594371948545', text='@Mark_Goldberg_ @Tesla Note the fabulous plaid jacket &amp; gingham shirt combo 🤣', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Mark_Goldberg_', 'name': 'Mark Goldberg', 'id': 932730431434211328, 'id_str': '932730431434211328', 'indices': [0, 15]}, {'screen_name': 'Tesla', 'name': 'Tesla', 'id': 13298072, 'id_str': '13298072', 'indices': [16, 22]}], 'urls': []}, source='Twitter for iPhone', source_url='http://twitter.com/download/iphone', in_reply_to_status_id=1292818184588886016, in_reply_to_status_id_str='1292818184588886016', in_reply_to_user_id=932730431434211328, in_reply_to_user_id_str='932730431434211328', in_reply_to_screen_name='Mark_Goldberg_', author=User(_api=<tweepy.api.API object at 0x7f037fe84f60>, _json={'id': 44196397, 'id_str': '44196397', 'name': 'Elon Musk', 'screen_name': 'elonmusk', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 37805892, 'friends_count': 95, 'listed_count': 55088, 'created_at': 'Tue Jun 02 20:12:29 +0000 2009', 'favourites_count': 6395, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 11972, 'lang': None, 'contributors_enabled': False, 'is_translator ...
#  Status(_api=<tweepy.api.API object at 0x7f037fe84f60>, _json={'created_at': 'Sun Aug 09 19:15:01 +0000 2020', 'id': 1292539902161166336, 'id_str': '1292539902161166336', 'text': '@archillect Twin Peaks', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'archillect', 'name': 'Archillect', 'id': 2907774137, 'id_str': '2907774137', 'indices': [0, 11]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1292539384152182784, 'in_reply_to_status_id_str': '1292539384152182784', 'in_reply_to_user_id': 2907774137, 'in_reply_to_user_id_str': '2907774137', 'in_reply_to_screen_name': 'archillect', 'user': {'id': 44196397, 'id_str': '44196397', 'name': 'Elon Musk', 'screen_name': 'elonmusk', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 37805892, 'friends_count': 95, 'listed_count': 55088, 'created_at': 'Tue Jun 02 20:12:29 +0000 2009', 'favourites_count': 6395, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 11972, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1289966861333835776/LVnVeLln_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1289966861333835776/LVnVeLln_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44196397/1576183471', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 423, 'favorite_count': 11952, 'favorited': False, 'retweeted': False, 'lang': 'et'}, created_at=datetime.datetime(2020, 8, 9, 19, 15, 1), id=1292539902161166336, id_str='1292539902161166336', text='@archillect Twin Peaks', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'archillect', 'name': 'Archillect', 'id': 2907774137, 'id_str': '2907774137', 'indices': [0, 11]}], 'urls': []}, source='Twitter for iPhone', source_url='http://twitter.com/download/iphone', in_reply_to_status_id=1292539384152182784, in_reply_to_status_id_str='1292539384152182784', in_reply_to_user_id=2907774137, in_reply_to_user_id_str='2907774137', in_reply_to_screen_name='archillect', author=User(_api=<tweepy.api.API object at 0x7f037fe84f60>, _json={'id': 44196397, 'id_str': '44196397', 'name': 'Elon Musk', 'screen_name': 'elonmusk', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 37805892, 'friends_count': 95, 'listed_count': 55088, 'created_at': 'Tue Jun 02 20:12:29 +0000 2009', 'favourites_count': 6395, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 11972, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1289966861333835776/LVnVeLln_normal.jpg', 'profile_image_url_ ...
#  Status(_api=<tweepy.api.API object at 0x7f037fe84f60>, _json={'created_at': 'Sun Aug 09 19:00:40 +0000 2020', 'id': 1292536289800019970, 'id_str': '1292536289800019970', 'text': '@SamTalksTesla Working on my Mom’s cousin’s farm in Saskatchewan at age 17. I think we did a barn-raising that day.', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'SamTalksTesla', 'name': 'Sam', 'id': 1646555828, 'id_str': '1646555828', 'indices': [0, 14]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1292039910313136129, 'in_reply_to_status_id_str': '1292039910313136129', 'in_reply_to_user_id': 1646555828, 'in_reply_to_user_id_str': '1646555828', 'in_reply_to_screen_name': 'SamTalksTesla', 'user': {'id': 44196397, 'id_str': '44196397', 'name': 'Elon Musk', 'screen_name': 'elonmusk', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 37805892, 'friends_count': 95, 'listed_count': 55088, 'created_at': 'Tue Jun 02 20:12:29 +0000 2009', 'favourites_count': 6395, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 11972, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1289966861333835776/LVnVeLln_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1289966861333835776/LVnVeLln_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44196397/1576183471', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 290, 'favorite_count': 12880, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 8, 9, 19, 0, 40), id=1292536289800019970, id_str='1292536289800019970', text='@SamTalksTesla Working on my Mom’s cousin’s farm in Saskatchewan at age 17. I think we did a barn-raising that day.', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'SamTalksTesla', 'name': 'Sam', 'id': 1646555828, 'id_str': '1646555828', 'indices': [0, 14]}], 'urls': []}, source='Twitter for iPhone', source_url='http://twitter.com/download/iphone', in_reply_to_status_id=1292039910313136129, in_reply_to_status_id_str='1292039910313136129', in_reply_to_user_id=1646555828, in_reply_to_user_id_str='1646555828', in_reply_to_screen_name='SamTalksTesla', author=User(_api=<tweepy.api.API object at 0x7f037fe84f60>, _json={'id': 44196397, 'id_str': '44196397', 'name': 'Elon Musk', 'screen_name': 'elonmusk', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 37805892, 'friends_count': 95, 'listed_count': 55088, 'created_at': 'Tue Jun 02 20:12:29 +0000 2009', 'favourites_count': 6395, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 11972, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com ...
# ...
#  Status(_api=<tweepy.api.API object at 0x7f037fe84f60>, _json={'created_at': 'Sat Aug 08 21:44:33 +0000 2020', 'id': 1292215145750360065, 'id_str': '1292215145750360065', 'text': '@PPathole @BernieSanders Over time, since we give all employees shares, my ownership is diluted automatically. From… https://t.co/AQgI0Cu2HN', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'PPathole', 'name': 'Pranay Pathole', 'id': 1291945442, 'id_str': '1291945442', 'indices': [0, 9]}, {'screen_name': 'BernieSanders', 'name': 'Bernie Sanders', 'id': 216776631, 'id_str': '216776631', 'indices': [10, 24]}], 'urls': [{'url': 'https://t.co/AQgI0Cu2HN', 'expanded_url': 'https://twitter.com/i/web/status/1292215145750360065', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1291933250273730561, 'in_reply_to_status_id_str': '1291933250273730561', 'in_reply_to_user_id': 1291945442, 'in_reply_to_user_id_str': '1291945442', 'in_reply_to_screen_name': 'PPathole', 'user': {'id': 44196397, 'id_str': '44196397', 'name': 'Elon Musk', 'screen_name': 'elonmusk', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 37805892, 'friends_count': 95, 'listed_count': 55088, 'created_at': 'Tue Jun 02 20:12:29 +0000 2009', 'favourites_count': 6395, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 11972, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1289966861333835776/LVnVeLln_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1289966861333835776/LVnVeLln_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44196397/1576183471', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 226, 'favorite_count': 2645, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 8, 8, 21, 44, 33), id=1292215145750360065, id_str='1292215145750360065', text='@PPathole @BernieSanders Over time, since we give all employees shares, my ownership is diluted automatically. From… https://t.co/AQgI0Cu2HN', truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'PPathole', 'name': 'Pranay Pathole', 'id': 1291945442, 'id_str': '1291945442', 'indices': [0, 9]}, {'screen_name': 'BernieSanders', 'name': 'Bernie Sanders', 'id': 216776631, 'id_str': '216776631', 'indices': [10, 24]}], 'urls': [{'url': 'https://t.co/AQgI0Cu2HN', 'expanded_url': 'https://twitter.com/i/web/status/1292215145750360065', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, source='Twitter for iPhone', source_url='http://twitter.com/download/iphone', in_reply_to_status_id=1291933250273730561, in_reply_to_status_id_str='1291933250273730561', in_reply_to_user_id=1291945442, in_reply_to_user_id_str='1291945442', in_reply_to_screen_name='PPathole', author=User(_api=<tweepy.api.API object at 0x7f037fe84f60>, _json={'id': 44196397, 'id_str': '44196397', 'name': 'Elon Musk', 'screen_name': 'elonmusk', 'locat ...
#  Status(_api=<tweepy.api.API object at 0x7f037fe84f60>, _json={'created_at': 'Sat Aug 08 21:02:28 +0000 2020', 'id': 1292204554738515968, 'id_str': '1292204554738515968', 'text': 'RT @ThePlanetaryGuy: Videos like this will always amaze me...\n\nAstronomer Jan Koet captured this video in 2007 of Saturn appearing behind t…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'ThePlanetaryGuy', 'name': 'Paul Byrne', 'id': 975735690498596864, 'id_str': '975735690498596864', 'indices': [3, 19]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 44196397, 'id_str': '44196397', 'name': 'Elon Musk', 'screen_name': 'elonmusk', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 37805892, 'friends_count': 95, 'listed_count': 55088, 'created_at': 'Tue Jun 02 20:12:29 +0000 2009', 'favourites_count': 6395, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 11972, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1289966861333835776/LVnVeLln_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1289966861333835776/LVnVeLln_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44196397/1576183471', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Fri Aug 07 21:01:07 +0000 2020', 'id': 1291841829185429507, 'id_str': '1291841829185429507', 'text': 'Videos like this will always amaze me...\n\nAstronomer Jan Koet captured this video in 2007 of Saturn appearing behin… https://t.co/XUGRqukVDn', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/XUGRqukVDn', 'expanded_url': 'https://twitter.com/i/web/status/1291841829185429507', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 975735690498596864, 'id_str': '975735690498596864', 'name': 'Paul Byrne', 'screen_name': 'ThePlanetaryGuy', 'location': 'Raleigh, NC', 'description': 'Associate Professor of Planetary Science at @NCState—endlessly driven to understand why planets look the way they do | he/him | 🇮🇪 in 🇺🇸', 'url': 'https://t.co/fJxciwmOPM', 'entities': {'url': {'urls': [{'url': 'https://t.co/fJxciwmOPM', 'expanded_url': 'http://planetaryresearchgroup.com', 'display_url': 'planetaryresearchgroup.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 7275, 'friends_count': 706, 'listed_count': 118, 'created_at': 'Mon Mar 19 14:08:11 +0000 2018', 'favourites_count': 77768, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 11260, 'lang': None, 'contrib ...
#  Status(_api=<tweepy.api.API object at 0x7f037fe84f60>, _json={'created_at': 'Sat Aug 08 19:51:49 +0000 2020', 'id': 1292186775809449985, 'id_str': '1292186775809449985', 'text': '@RationalEtienne @BernieSanders I wonder if he reads his Twitter feed', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'RationalEtienne', 'name': 'Pope of Muskanity 🦆', 'id': 2241150253, 'id_str': '2241150253', 'indices': [0, 16]}, {'screen_name': 'BernieSanders', 'name': 'Bernie Sanders', 'id': 216776631, 'id_str': '216776631', 'indices': [17, 31]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1292186219686879232, 'in_reply_to_status_id_str': '1292186219686879232', 'in_reply_to_user_id': 2241150253, 'in_reply_to_user_id_str': '2241150253', 'in_reply_to_screen_name': 'RationalEtienne', 'user': {'id': 44196397, 'id_str': '44196397', 'name': 'Elon Musk', 'screen_name': 'elonmusk', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 37805892, 'friends_count': 95, 'listed_count': 55088, 'created_at': 'Tue Jun 02 20:12:29 +0000 2009', 'favourites_count': 6395, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 11972, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1289966861333835776/LVnVeLln_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1289966861333835776/LVnVeLln_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44196397/1576183471', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 158, 'favorite_count': 4259, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 8, 8, 19, 51, 49), id=1292186775809449985, id_str='1292186775809449985', text='@RationalEtienne @BernieSanders I wonder if he reads his Twitter feed', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'RationalEtienne', 'name': 'Pope of Muskanity 🦆', 'id': 2241150253, 'id_str': '2241150253', 'indices': [0, 16]}, {'screen_name': 'BernieSanders', 'name': 'Bernie Sanders', 'id': 216776631, 'id_str': '216776631', 'indices': [17, 31]}], 'urls': []}, source='Twitter for iPhone', source_url='http://twitter.com/download/iphone', in_reply_to_status_id=1292186219686879232, in_reply_to_status_id_str='1292186219686879232', in_reply_to_user_id=2241150253, in_reply_to_user_id_str='2241150253', in_reply_to_screen_name='RationalEtienne', author=User(_api=<tweepy.api.API object at 0x7f037fe84f60>, _json={'id': 44196397, 'id_str': '44196397', 'name': 'Elon Musk', 'screen_name': 'elonmusk', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 37805892, 'friends_count': 95, 'listed_count': 55088, 'created_at': 'Tue Jun 02 20:12:29 +0000 2009', 'favourites_count': 6395, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 11972, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': ...

# %%
tweets[1].text
# Out:
# '@Teslarati Aiming to make it super fun!'

# %%
tweets = twitter_user.timeline(count=200,
                               exclude_replies=True,
                               include_rts=False,
                               # since=1,
                               tweet_mode='extended')
print(len(tweets))
# Out:
# 24

# %%
tweets[1].full_text
# Out:
# 'Good piece on Giga Berlin construction https://t.co/pA8sgEpV9Y'

# %%
embedding = BASILICA.embed_sentence(tweets[1].full_text, model='twitter')
len(embedding)
# Out:
# 768

# %%
def add_user_tweepy(username):
  '''Add a user and their tweets to database'''
  try:
    # Get user info from tweepy
    twitter_user = TWITTER.get_user(username)

    # Get tweets ignoring re-tweets and replies
    tweets = twitter_user.timeline(count=200,
                                   exclude_replies=True,
                                   include_rts=False,
                                   tweet_mode='extended')
    
    # Get an examble basilica embedding for first tweet
    embedding = BASILICA.embed_sentence(tweets[0].full_text, model='twitter')

  except Exception as e:
    print('Error processing {}: {}'.format(username, e))
    raise e

  return tweets, embedding

# %%
elon_tweets, elon_embedding = add_user_tweepy('elonmusk')
print(len(elon_tweets), len(elon_embedding))
# Out:
# 24 768

# %% [markdown]
# ### Twitter Scraper (for those without API access)

# %%
# !pip install twitter_scraper
# Out:
# Collecting twitter_scraper
#   Downloading https://files.pythonhosted.org/packages/27/b0/c02c3dce0c1d501478230d47cabb611a1b10fec907ee5a01d814316d9ee1/twitter_scraper-0.4.4-py2.py3-none-any.whl
# Collecting MechanicalSoup
#   Downloading https://files.pythonhosted.org/packages/0b/fe/4f871ec3379080c5979815bfec3266871e555eebf4879f551a7e5dee4766/MechanicalSoup-0.12.0-py2.py3-none-any.whl
# Collecting requests-html
#   Downloading https://files.pythonhosted.org/packages/24/bc/a4380f09bab3a776182578ce6b2771e57259d0d4dbce178205779abdc347/requests_html-0.10.0-py3-none-any.whl
# Requirement already satisfied: requests>=2.0 in /usr/local/lib/python3.6/dist-packages (from MechanicalSoup->twitter_scraper) (2.23.0)
# Requirement already satisfied: beautifulsoup4>=4.4 in /usr/local/lib/python3.6/dist-packages (from MechanicalSoup->twitter_scraper) (4.6.3)
# Requirement already satisfied: six>=1.4 in /usr/local/lib/python3.6/dist-packages (from MechanicalSoup->twitter_scraper) (1.15.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.6/dist-packages (from MechanicalSoup->twitter_scraper) (4.2.6)
# Collecting parse
#   Downloading https://files.pythonhosted.org/packages/22/35/930b6d670cac8ead61dfc05f0e62994ab0697573de17a3231d65631f16d5/parse-1.16.0.tar.gz
# Collecting pyquery
#   Downloading https://files.pythonhosted.org/packages/78/43/95d42e386c61cb639d1a0b94f0c0b9f0b7d6b981ad3c043a836c8b5bc68b/pyquery-1.4.1-py2.py3-none-any.whl
# Collecting w3lib
#   Downloading https://files.pythonhosted.org/packages/a3/59/b6b14521090e7f42669cafdb84b0ab89301a42f1f1a82fcf5856661ea3a7/w3lib-1.22.0-py2.py3-none-any.whl
# Requirement already satisfied: bs4 in /usr/local/lib/python3.6/dist-packages (from requests-html->twitter_scraper) (0.0.1)
# Collecting fake-useragent
#   Downloading https://files.pythonhosted.org/packages/d1/79/af647635d6968e2deb57a208d309f6069d31cb138066d7e821e575112a80/fake-useragent-0.1.11.tar.gz
# Collecting pyppeteer>=0.0.14
#   Downloading https://files.pythonhosted.org/packages/5d/4b/3c2aabdd1b91fa52aa9de6cde33b488b0592b4d48efb0ad9efbf71c49f5b/pyppeteer-0.2.2-py3-none-any.whl (145kB)
#      |████████████████████████████████| 153kB 16.5MB/s
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->MechanicalSoup->twitter_scraper) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->MechanicalSoup->twitter_scraper) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->MechanicalSoup->twitter_scraper) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->MechanicalSoup->twitter_scraper) (2020.6.20)
# Collecting cssselect>0.7.9
#   Downloading https://files.pythonhosted.org/packages/3b/d4/3b5c17f00cce85b9a1e6f91096e1cc8e8ede2e1be8e96b87ce1ed09e92c5/cssselect-1.1.0-py2.py3-none-any.whl
# Collecting appdirs<2.0.0,>=1.4.3
#   Downloading https://files.pythonhosted.org/packages/3b/00/2344469e2084fb287c2e0b57b72910309874c3245463acd6cf5e3db69324/appdirs-1.4.4-py2.py3-none-any.whl
# Collecting tqdm<5.0.0,>=4.42.1
#   Downloading https://files.pythonhosted.org/packages/28/7e/281edb5bc3274dfb894d90f4dbacfceaca381c2435ec6187a2c6f329aed7/tqdm-4.48.2-py2.py3-none-any.whl (68kB)
#      |████████████████████████████████| 71kB 9.0MB/s
# Collecting pyee<8.0.0,>=7.0.1
#   Downloading https://files.pythonhosted.org/packages/f6/28/1cedd44c27907f1507a28ff2d36fc6cdb981c9deff2fa288bc48a700c7c9/pyee-7.0.2-py2.py3-none-any.whl
# Collecting websockets<9.0,>=8.1
#   Downloading https://files.pythonhosted.org/packages/bb/d9/856af84843912e2853b1b6e898ac8b802989fcf9ecf8e8445a1da263bf3b/websockets-8.1-cp36-cp36m-manylinux2010_x86_64.whl (78kB)
#      |████████████████████████████████| 81kB 9.6MB/s
# Building wheels for collected packages: parse, fake-useragent
#   Building wheel for parse (setup.py) ... done
#   Created wheel for parse: filename=parse-1.16.0-cp36-none-any.whl size=23996 sha256=358e47b380c294ec3fb0bce5102771964725023725e508379db274024608030e
#   Stored in directory: /root/.cache/pip/wheels/46/ca/7d/4e6d687c81f1110b47140845d6dce4e6d7cdae0996caeca560
#   Building wheel for fake-useragent (setup.py) ... done
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-cp36-none-any.whl size=13484 sha256=2aab05ce63bbdb936021fdae5cf177fd597d5b9f8f32b9148497a9d28fa8452d
#   Stored in directory: /root/.cache/pip/wheels/5e/63/09/d1dc15179f175357d3f5c00cbffbac37f9e8690d80545143ff
# Successfully built parse fake-useragent
# ERROR: pyppeteer 0.2.2 has requirement urllib3<2.0.0,>=1.25.8, but you'll have urllib3 1.24.3 which is incompatible.
# Installing collected packages: MechanicalSoup, parse, cssselect, pyquery, w3lib, fake-useragent, appdirs, tqdm, pyee, websockets, pyppeteer, requests-html, twitter-scraper
#   Found existing installation: tqdm 4.41.1
#     Uninstalling tqdm-4.41.1:
#       Successfully uninstalled tqdm-4.41.1
# Successfully installed MechanicalSoup-0.12.0 appdirs-1.4.4 cssselect-1.1.0 fake-useragent-0.1.11 parse-1.16.0 pyee-7.0.2 pyppeteer-0.2.2 pyquery-1.4.1 requests-html-0.10.0 tqdm-4.48.2 twitter-scraper-0.4.4 w3lib-1.22.0 websockets-8.1

# %%
from twitter_scraper import get_tweets, Profile

# %%
elon_profile = Profile('elonmusk')
dir(elon_profile)

# %%
elon_profile.tweets_count
# Out:
# 11937

# %%
tweets = list(get_tweets('elonmusk', pages=25))
print(len(tweets))
# Out:
# 499

# %%
tweets[0:3]
# Out:
# [{'entries': {'hashtags': [],
#    'photos': ['https://pbs.twimg.com/media/EexYPnPU0AEqLUI.jpg'],
#    'urls': [],
#    'videos': []},
#   'isPinned': False,
#   'isRetweet': False,
#   'likes': 77167,
#   'replies': 2679,
#   'retweets': 6105,
#   'text': 'SN5 pic.twitter.com/GlZ28KFVHU',
#   'time': datetime.datetime(2020, 8, 6, 22, 39, 35),
#   'tweetId': '1291504220948951041',
#   'tweetUrl': '/elonmusk/status/1291504220948951041',
#   'userId': '44196397',
#   'username': 'elonmusk'},
#  {'entries': {'hashtags': [],
#    'photos': [],
#    'urls': [],
#    'videos': [{'id': '1GqqSQZpS-faQ0Nb'}]},
#   'isPinned': False,
#   'isRetweet': True,
#   'likes': 42334,
#   'replies': 996,
#   'retweets': 3872,
#   'text': 'Looking up in Model Y pic.twitter.com/iAfpJ491Zz',
#   'time': datetime.datetime(2020, 8, 6, 0, 58, 38),
#   'tweetId': '1291176823557099520',
#   'tweetUrl': '/Tesla/status/1291176823557099520',
#   'userId': '13298072',
#   'username': 'Tesla'},
#  {'entries': {'hashtags': [],
#    'photos': [],
#    'urls': [],
#    'videos': [{'id': 'PQ6-Nc_vhUazq9m9'}]},
#   'isPinned': False,
#   'isRetweet': True,
#   'likes': 246259,
#   'replies': 5363,
#   'retweets': 47983,
#   'text': 'Starship takes flight pic.twitter.com/IWvwcA05hl',
#   'time': datetime.datetime(2020, 8, 5, 3, 37, 40),
#   'tweetId': '1290854457136181248',
#   'tweetUrl': '/SpaceX/status/1290854457136181248',
#   'userId': '34743251',
#   'username': 'SpaceX'}]

# %%
original_tweets = [d for d in tweets if d['username']=='elonmusk']
print(len(original_tweets))
# Out:
# 364

# %%
original_tweets[0]['text']
# Out:
# 'SN5 pic.twitter.com/GlZ28KFVHU'

# %%
def add_user_twitter_scraper(username):
    """Add a user and their tweets to database."""
    try:
        # Get user profile   
        user_profile = list(get_tweets(username, pages=25))

        # Get most recent tweets
        tweets = list(get_tweets(username, pages=10))
        original_tweets = [d for d in tweets if d['username']==username]

        # Get an example Basilica embedding for first tweet
        embedding = BASILICA.embed_sentence(original_tweets[0]['text'], model='twitter')
            
    except Exception as e:
        print('Error processing {}: {}'.format(username, e))
        raise e

    return original_tweets, embedding

# %%
elon_tweets, elon_embedding = add_user_twitter_scraper('elonmusk')
print(len(elon_tweets), len(elon_embedding))
# Out:
# 133 768
